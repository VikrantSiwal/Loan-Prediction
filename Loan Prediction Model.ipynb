# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("D:\\Projects\\Data Science\\Loan Prediction\\train.csv")

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.dropna(inplace=True)
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# ...

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       480.000000         480.000000  480.000000        480.000000
# mean       5364.231250        1581.093583  144.735417        342.050000
# std        5668.251251        2617.692267   80.508164         65.212401
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2898.750000           0.000000  100.000000        360.000000
# 50%        3859.000000        1084.500000  128.000000        360.000000
# 75%        5852.500000        2253.250000  170.000000        360.000000
# max       81000.000000       33837.000000  600.000000        480.000000
#
#        Credit_History
# count      480.000000
# mean         0.854167
# std          0.353307
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
len(data)
# Out:
# 480

# %%
data['Gender'].value_counts()
# Out:
# Male      394
# Female     86
# Name: Gender, dtype: int64

# %%
data['Married'].value_counts()
# Out:
# Yes    311
# No     169
# Name: Married, dtype: int64

# %%
data['Dependents'].value_counts()
# Out:
# 0     274
# 2      85
# 1      80
# 3+     41
# Name: Dependents, dtype: int64

# %%
data['Education'].value_counts()
# Out:
# Graduate        383
# Not Graduate     97
# Name: Education, dtype: int64

# %%
data['Self_Employed'].value_counts()
# Out:
# No     414
# Yes     66
# Name: Self_Employed, dtype: int64

# %%
data['Property_Area'].value_counts()
# Out:
# Semiurban    191
# Urban        150
# Rural        139
# Name: Property_Area, dtype: int64

# %%
data=data.drop('Gender',axis=1)

# %%
data.head()
# Out:
#     Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1  LP001003     Yes          1      Graduate            No             4583
# 2  LP001005     Yes          0      Graduate           Yes             3000
# 3  LP001006     Yes          0  Not Graduate            No             2583
# 4  LP001008      No          0      Graduate            No             6000
# 5  LP001011     Yes          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
data=data.replace({'Married':{'Yes':0,'No':1}})

# %%
data.head()
# Out:
#     Loan_ID  Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1  LP001003        0          1      Graduate            No             4583
# 2  LP001005        0          0      Graduate           Yes             3000
# 3  LP001006        0          0  Not Graduate            No             2583
# 4  LP001008        1          0      Graduate            No             6000
# 5  LP001011        0          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
data=data.replace({'Self_Employed':{'Yes':0,'No':1}})

# %%
data.head()
# Out:
#     Loan_ID  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1  LP001003        0          1          1              1             4583
# 2  LP001005        0          0          1              0             3000
# 3  LP001006        0          0          0              1             2583
# 4  LP001008        1          0          1              1             6000
# 5  LP001011        0          2          1              0             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
data=data.replace({'Property_Area':{'Rural':0,'Urban':1,'Semiurban':2}})

# %%
data.head()
# Out:
#     Loan_ID  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1  LP001003        0          1          1              1             4583
# 2  LP001005        0          0          1              0             3000
# 3  LP001006        0          0          0              1             2583
# 4  LP001008        1          0          1              1             6000
# 5  LP001011        0          2          1              0             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#    Property_Area Loan_Status
# 1              0           N
# 2              1           Y
# ...

# %%
data.shape
# Out:
# (480, 12)

# %%
X=data.iloc[:,1:11]

# %%
X.head()
# Out:
#    Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1        0          1          1              1             4583
# 2        0          0          1              0             3000
# 3        0          0          0              1             2583
# 4        1          0          1              1             6000
# 5        0          2          1              0             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#    Property_Area
# 1              0
# 2              1
# 3              1
# 4              1
# 5              1

# %%
Y=data.iloc[:,11]

# %%
data.head()
# Out:
#     Loan_ID  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1  LP001003        0          1          1              1             4583
# 2  LP001005        0          0          1              0             3000
# 3  LP001006        0          0          0              1             2583
# 4  LP001008        1          0          1              1             6000
# 5  LP001011        0          2          1              0             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#    Property_Area Loan_Status
# 1              0           N
# 2              1           Y
# ...

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

# %%
X.dtypes
# Out:
# Married                int64
# Dependents            object
# Education              int64
# Self_Employed          int64
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int64
# dtype: object

# %%
Y.dtypes
# Out:
# dtype('O')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
X['Dependents']=LabelEncoder().fit_transform(X['Dependents'])

# %%
X['Dependents'].value_counts()
# Out:
# 0    274
# 2     85
# 1     80
# 3     41
# Name: Dependents, dtype: int64

# %%
model = LogisticRegression()
model.fit(X,Y)
predictions = model.predict(X)
print(accuracy_score(Y, predictions))
# Out:
# 0.81875

# %%
X_test=pd.read_csv("D:\\Projects\\Data Science\\Loan Prediction\\test.csv")

# %%
X_test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
Xtest=X_test.drop('Gender',axis=1)

# %%
Xtest=Xtest.replace({'Married':{'Yes':0,'No':1}})
Xtest=Xtest.replace({'Self_Employed':{'Yes':0,'No':1}})
Xtest=Xtest.replace({'Property_Area':{'Rural':0,'Urban':1,'Semiurban':2}})

# %%
Xtest.head()
# Out:
#     Loan_ID  Married Dependents     Education  Self_Employed  ApplicantIncome  \
# 0  LP001015        0          0      Graduate            1.0             5720
# 1  LP001022        0          1      Graduate            1.0             3076
# 2  LP001031        0          2      Graduate            1.0             5000
# 3  LP001035        0          2      Graduate            1.0             2340
# 4  LP001051        1          0  Not Graduate            1.0             3276
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0       110.0             360.0             1.0
# 1               1500       126.0             360.0             1.0
# 2               1800       208.0             360.0             1.0
# 3               2546       100.0             360.0             NaN
# 4                  0        78.0             360.0             1.0
#
#    Property_Area
# 0              1
# 1              1
# 2              1
# 3              1
# ...

# %%
Xtest=Xtest.replace({'Education':{'Graduate':1,'Not Graduate':0}})

# %%
Xtest.head()
# Out:
#     Loan_ID  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  LP001015        0          0          1            1.0             5720
# 1  LP001022        0          1          1            1.0             3076
# 2  LP001031        0          2          1            1.0             5000
# 3  LP001035        0          2          1            1.0             2340
# 4  LP001051        1          0          0            1.0             3276
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0       110.0             360.0             1.0
# 1               1500       126.0             360.0             1.0
# 2               1800       208.0             360.0             1.0
# 3               2546       100.0             360.0             NaN
# 4                  0        78.0             360.0             1.0
#
#    Property_Area
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
Xtest['Dependents'].value_counts()
# Out:
# 0     200
# 2      59
# 1      58
# 3+     40
# Name: Dependents, dtype: int64

# %%
Xtest=Xtest.replace({'Dependents':{'0':0,'1':1,'2':2,'3+':3}})

# %%
Xtest.dtypes
# Out:
# Loan_ID               object
# Married                int64
# Dependents           float64
# Education              int64
# Self_Employed        float64
# ApplicantIncome        int64
# CoapplicantIncome      int64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int64
# dtype: object

# %%
Xtest.shape
# Out:
# (367, 11)

# %%
X_test=Xtest.iloc[:,1:11]

# %%
X_test.isnull().sum()
# Out:
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
X_test=X_test.fillna(X_test.median())

# %%
X_test.isnull().sum()
# Out:
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
X_test.head(18)
# Out:
#     Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         0         0.0          1            1.0             5720
# 1         0         1.0          1            1.0             3076
# 2         0         2.0          1            1.0             5000
# 3         0         2.0          1            1.0             2340
# 4         1         0.0          0            1.0             3276
# 5         0         0.0          0            0.0             2165
# 6         1         1.0          0            1.0             2226
# 7         0         2.0          0            1.0             3881
# 8         0         2.0          1            1.0            13633
# 9         1         0.0          0            1.0             2400
# 10        1         0.0          0            1.0             3091
# 11        0         1.0          1            1.0             2185
# 12        1         3.0          1            1.0             4166
# ...

# %%
predict_model=model.predict(X_test)

# %%
predict_model1=pd.DataFrame(data=predict_model)

# %%
writer = pd.ExcelWriter('D:\\Projects\\Data Science\\Loan Prediction\\Result.xlsx')

# %%
Xtest['Loan_ID'].to_excel(writer,'Sheet1')

# %%
predict_model1.to_excel(writer,'Sheet2')

# %%
writer.save()
